# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network
import ipaddress

from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()
                     
slice_name = 'BF3'
#site = fablib.get_random_site()

node1_name = 'Node1'
node2_name = 'Node2'
node3_name = 'Node3'

slice = fablib.get_slice(slice_name)

Node1 = slice.get_node(name=node1_name)        
Node2 = slice.get_node(name=node2_name)
Node3 = slice.get_node(name=node3_name)
# Out:
# User: elizalds@email.sc.edu bastion key is valid!
# Configuration is valid

# %%
Node1.get_ssh_command()
# Out:
# 'ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3040:f816:3eff:fe0a:ee68'

# %%
Node2.get_ssh_command()
# Out:
# 'ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3040:f816:3eff:fed9:1a37'

# %%
Node3.get_ssh_command()
# Out:
# 'ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3040:f816:3eff:fe06:7b80'

# %%
Node2.download_file('attack_rf.c','/home/ubuntu/rf_attack/attack_rf.c')

# %%
Node2.upload_file('random_forest_ws8_trees1_depth8.json', '/home/ubuntu/rf_attack/random_forest_ws8_trees1_depth8.json')
Node2.upload_file('random_forest_ws8_trees5_depth8.json', '/home/ubuntu/rf_attack/random_forest_ws8_trees5_depth8.json')
Node2.upload_file('random_forest_ws8_trees10_depth8.json', '/home/ubuntu/rf_attack/random_forest_ws8_trees10_depth8.json')
Node2.upload_file('random_forest_ws8_trees25_depth8.json', '/home/ubuntu/rf_attack/random_forest_ws8_trees25_depth8.json')
Node2.upload_file('random_forest_ws8_trees50_depth8.json', '/home/ubuntu/rf_attack/random_forest_ws8_trees50_depth8.json')
Node2.upload_file('test_data.h', '/home/ubuntu/rf_attack/test_data.h')
# Out:
# <SFTPAttributes: [ size=47863140 uid=1000 gid=1000 mode=0o100664 atime=1775607539 mtime=1775607542 ]>

# %%
Node2.upload_file('attack_rf.c', '/home/ubuntu/rf_attack/attack_rf.c')
# Out:
# <SFTPAttributes: [ size=13042 uid=1000 gid=1000 mode=0o100664 atime=1775607973 mtime=1775608888 ]>

# %%
Node2.upload_file('attack_rf_demo.c', '/home/ubuntu/rf_attack/attack_rf_demo.c')
# Out:
# <SFTPAttributes: [ size=15150 uid=1000 gid=1000 mode=0o100664 atime=1775619453 mtime=1775619625 ]>
